# %%
import pandas as pd

# create simple dataset
data = {
    "City": ["Kathmandu", "Pokhara", "Lalitpur"],
    "Population": [1000000, 300000, 500000]
}

df = pd.DataFrame(data)

print(df)
# Out:
#         City  Population
# 0  Kathmandu     1000000
# 1    Pokhara      300000
# 2   Lalitpur      500000
